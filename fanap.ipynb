# %% [markdown]
# 10

# %%
import numpy as np
import pandas as pd
import os
import sys
import random
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv(r"E:\github\fanap\melb_data.csv")
data.drop("Unnamed: 0", axis=1, inplace=True)
data
# Out:
#              Suburb           Address  Rooms Type      Price Method
# 0        Abbotsford      85 Turner St      2    h  1480000.0      S  \
# 1        Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 2        Abbotsford      5 Charles St      3    h  1465000.0     SP
# 3        Abbotsford  40 Federation La      3    h   850000.0     PI
# 4        Abbotsford       55a Park St      4    h  1600000.0     VB
# ...             ...               ...    ...  ...        ...    ...
# 18391  Williamstown   8/2 Thompson St      2    t   622500.0     SP
# 18392  Williamstown      96 Verdon St      4    h  2500000.0     PI
# 18393     Yallambie      17 Amaroo Wy      4    h  1100000.0      S
# 18394    Yarraville        6 Agnes St      4    h  1285000.0     SP
# 18395    Yarraville     33 Freeman St      4    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  ...  Bathroom  Car
# 0          Biggin   3/12/2016       2.5    3067.0  ...       1.0  1.0  \
# 1          Biggin   4/02/2016       2.5    3067.0  ...       1.0  0.0
# 2          Biggin   4/03/2017       2.5    3067.0  ...       2.0  0.0
# 3          Biggin   4/03/2017       2.5    3067.0  ...       2.0  1.0
# 4          Nelson   4/06/2016       2.5    3067.0  ...       1.0  2.0
# ...           ...         ...       ...       ...  ...       ...  ...
# 18391        Greg  26/08/2017       6.8    3016.0  ...       2.0  1.0
# 18392     Sweeney  26/08/2017       6.8    3016.0  ...       1.0  5.0
# 18393  Buckingham  26/08/2017      12.7    3085.0  ...       3.0  2.0
# 18394     Village  26/08/2017       6.3    3013.0  ...       1.0  1.0
# 18395     Village  26/08/2017       6.3    3013.0  ...       2.0  2.0
#
#        Landsize  BuildingArea  YearBuilt  CouncilArea Lattitude  Longtitude
# 0         202.0           NaN        NaN        Yarra -37.79960   144.99840  \
# 1         156.0          79.0     1900.0        Yarra -37.80790   144.99340
# 2         134.0         150.0     1900.0        Yarra -37.80930   144.99440
# 3          94.0           NaN        NaN        Yarra -37.79690   144.99690
# 4         120.0         142.0     2014.0        Yarra -37.80720   144.99410
# ...         ...           ...        ...          ...       ...         ...
# 18391       NaN          89.0     2010.0          NaN -37.86393   144.90484
# 18392     866.0         157.0     1920.0          NaN -37.85908   144.89299
# 18393       NaN           NaN        NaN          NaN -37.72006   145.10547
# 18394     362.0         112.0     1920.0          NaN -37.81188   144.88449
# 18395       NaN         139.0     1950.0          NaN -37.81829   144.87404
#
#                   Regionname Propertycount
# 0      Northern Metropolitan        4019.0
# 1      Northern Metropolitan        4019.0
# 2      Northern Metropolitan        4019.0
# 3      Northern Metropolitan        4019.0
# 4      Northern Metropolitan        4019.0
# ...                      ...           ...
# 18391   Western Metropolitan        6380.0
# 18392   Western Metropolitan        6380.0
# 18393  Northern Metropolitan        1369.0
# 18394   Western Metropolitan        6543.0
# 18395   Western Metropolitan        6543.0
#
# [18396 rows x 21 columns]

# %%
data[["Address"]]
# Out:
#                 Address
# 0          85 Turner St
# 1       25 Bloomburg St
# 2          5 Charles St
# 3      40 Federation La
# 4           55a Park St
# ...                 ...
# 18391   8/2 Thompson St
# 18392      96 Verdon St
# 18393      17 Amaroo Wy
# 18394        6 Agnes St
# 18395     33 Freeman St
#
# [18396 rows x 1 columns]

# %%
data.groupby("Type")["Price"].mean()
# Out:
# Type
# h    1.234251e+06
# t    9.240601e+05
# u    6.187154e+05
# Name: Price, dtype: float64

# %%
data.groupby("Type")["Price"].aggregate(lambda x: x.sum()/len(x))
# Out:
# Type
# h    1.234251e+06
# t    9.240601e+05
# u    6.187154e+05
# Name: Price, dtype: float64

# %%
df = pd.read_csv(r"E:\github\fanap\learn\bank-additional-full.csv", sep=";")
df
# Out:
#        age          job  marital            education  default housing loan
# 0       56    housemaid  married             basic.4y       no      no   no  \
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous
# 0      telephone   may         mon       261         1    999         0  \
# 1      telephone   may         mon       149         1    999         0
# 2      telephone   may         mon       226         1    999         0
# 3      telephone   may         mon       151         1    999         0
# 4      telephone   may         mon       307         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 41183   cellular   nov         fri       334         1    999         0
# 41184   cellular   nov         fri       383         1    999         0
# 41185   cellular   nov         fri       189         2    999         0
# 41186   cellular   nov         fri       442         1    999         0
# 41187   cellular   nov         fri       239         3    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 0      nonexistent           1.1          93.994          -36.4      4.857  \
# 1      nonexistent           1.1          93.994          -36.4      4.857
# 2      nonexistent           1.1          93.994          -36.4      4.857
# 3      nonexistent           1.1          93.994          -36.4      4.857
# 4      nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 41183  nonexistent          -1.1          94.767          -50.8      1.028
# 41184  nonexistent          -1.1          94.767          -50.8      1.028
# 41185  nonexistent          -1.1          94.767          -50.8      1.028
# 41186  nonexistent          -1.1          94.767          -50.8      1.028
# 41187      failure          -1.1          94.767          -50.8      1.028
#
#        nr.employed    y
# 0           5191.0   no
# 1           5191.0   no
# 2           5191.0   no
# 3           5191.0   no
# 4           5191.0   no
# ...            ...  ...
# 41183       4963.6  yes
# 41184       4963.6   no
# 41185       4963.6   no
# 41186       4963.6  yes
# 41187       4963.6   no
#
# [41188 rows x 21 columns]

# %%
df.describe(include="object")
# Out:
#            job  marital          education default housing   loan   contact
# count    41188    41188              41188   41188   41188  41188     41188  \
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq     10422    24928              12168   32588   21576  33950     26144
#
#         month day_of_week     poutcome      y
# count   41188       41188        41188  41188
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    13769        8623        35563  36548

# %%
df["marital"].value_counts(normalize=True)
# Out:
# marital
# married     0.605225
# single      0.280859
# divorced    0.111974
# unknown     0.001942
# Name: proportion, dtype: float64

# %%
df.sort_values(["age","duration"], ascending=True).head()
# Out:
#        age      job marital education default  housing     loan   contact
# 37558   17  student  single  basic.9y      no      yes       no  cellular  \
# 37539   17  student  single  basic.9y      no      yes       no  cellular
# 37140   17  student  single   unknown      no      yes       no  cellular
# 37579   17  student  single  basic.9y      no  unknown  unknown  cellular
# 38274   17  student  single   unknown      no       no      yes  cellular
#
#       month day_of_week  duration  campaign  pdays  previous poutcome
# 37558   aug         fri        92         3      4         2  success  \
# 37539   aug         fri       182         2    999         2  failure
# 37140   aug         wed       432         3      4         2  success
# 37579   aug         fri       498         2    999         1  failure
# 38274   oct         tue       896         1      2         2  success
#
#        emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# 37558          -2.9          92.201          -31.4      0.869       5076.2  \
# 37539          -2.9          92.201          -31.4      0.869       5076.2
# 37140          -2.9          92.201          -31.4      0.884       5076.2
# 37579          -2.9          92.201          -31.4      0.869       5076.2
# 38274          -3.4          92.431          -26.9      0.742       5017.5
#
#          y
# 37558   no
# 37539   no
# 37140   no
# 37579  yes
# 38274  yes

# %%
df.apply(np.max)
# Out:
# age                      98
# job                 unknown
# marital             unknown
# education           unknown
# default                 yes
# housing                 yes
# loan                    yes
# contact           telephone
# month                   sep
# day_of_week             wed
# duration               4918
# campaign                 56
# pdays                   999
# previous                  7
# poutcome            success
# emp.var.rate            1.4
# cons.price.idx       94.767
# cons.conf.idx         -26.9
# euribor3m             5.045
# nr.employed          5228.1
# y                       yes
# dtype: object

# %%
df[["age","duration"]].apply(lambda x: x[x<30])
# Out:
#         age  duration
# 8      24.0       NaN
# 9      25.0       NaN
# 11     25.0       NaN
# 12     29.0       NaN
# 45      NaN      22.0
# ...     ...       ...
# 41143  29.0       NaN
# 41145  26.0       NaN
# 41147  25.0       NaN
# 41152  26.0       NaN
# 41182  29.0       NaN
#
# [7087 rows x 2 columns]

# %%
df[((df["age"] < 50) & (df["duration"] < 50))]
# Out:
#        age          job  marital            education  default housing loan
# 20      30   unemployed  married          high.school       no      no   no  \
# 45      42   technician   single  professional.course  unknown      no   no
# 84      38   technician   single    university.degree       no      no  yes
# 105     43     services   single          high.school  unknown      no   no
# 162     40  blue-collar  married             basic.9y  unknown      no   no
# ...    ...          ...      ...                  ...      ...     ...  ...
# 40967   34      student   single  professional.course       no     yes   no
# 40997   25      student  married          high.school       no     yes   no
# 40998   34   technician  married    university.degree       no     yes   no
# 41048   25      student   single          high.school       no     yes   no
# 41060   46       admin.  married             basic.9y       no     yes   no
#
#          contact month day_of_week  duration  campaign  pdays  previous
# 20     telephone   may         mon        38         1    999         0  \
# 45     telephone   may         mon        22         1    999         0
# 84     telephone   may         mon        20         1    999         0
# 105    telephone   may         mon        21         1    999         0
# 162    telephone   may         mon        46         1    999         0
# ...          ...   ...         ...       ...       ...    ...       ...
# 40967  telephone   oct         fri         6         1    999         0
# 40997  telephone   oct         wed         7         1    999         0
# 40998  telephone   oct         wed         5         1    999         0
# 41048  telephone   oct         tue        17         1    999         0
# 41060  telephone   nov         tue        18         1    999         1
#
#           poutcome  emp.var.rate  cons.price.idx  cons.conf.idx  euribor3m
# 20     nonexistent           1.1          93.994          -36.4      4.857  \
# 45     nonexistent           1.1          93.994          -36.4      4.857
# 84     nonexistent           1.1          93.994          -36.4      4.857
# 105    nonexistent           1.1          93.994          -36.4      4.857
# 162    nonexistent           1.1          93.994          -36.4      4.857
# ...            ...           ...             ...            ...        ...
# 40967  nonexistent          -1.1          94.601          -49.5      0.993
# 40997  nonexistent          -1.1          94.601          -49.5      1.016
# 40998  nonexistent          -1.1          94.601          -49.5      1.016
# 41048  nonexistent          -1.1          94.601          -49.5      1.037
# 41060      failure          -1.1          94.767          -50.8      1.047
#
#        nr.employed   y
# 20          5191.0  no
# 45          5191.0  no
# 84          5191.0  no
# 105         5191.0  no
# 162         5191.0  no
# ...            ...  ..
# 40967       4963.6  no
# 40997       4963.6  no
# 40998       4963.6  no
# 41048       4963.6  no
# 41060       4963.6  no
#
# [2544 rows x 21 columns]

# %%
d = {"no":0, "yes":1}
df["y"] = df["y"].map(d)
df["y"]
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 41183    1
# 41184    0
# 41185    0
# 41186    1
# 41187    0
# Name: y, Length: 41188, dtype: int64

# %%
pd.crosstab(df["y"], df["marital"])
# Out:
# marital  divorced  married  single  unknown
# y
# 0            4136    22396    9948       68
# 1             476     2532    1620       12

# %%
df.pivot_table(
    ["age", "duration"],
    ["job"], aggfunc = "mean").head(10)
# Out:
#                      age    duration
# job
# admin.         38.187296  254.312128
# blue-collar    39.555760  264.542360
# entrepreneur   41.723214  263.267857
# housemaid      45.500000  250.454717
# management     42.362859  257.058140
# retired        62.027326  273.712209
# self-employed  39.949331  264.142153
# services       37.926430  258.398085
# student        25.894857  283.683429
# technician     38.507638  250.232241

# %%
df.pivot_table(
    ["age", "campaign"],
    ["education"],
    aggfunc = ["mean", "count"],
)
# Out:
#                           mean            count
#                            age  campaign    age campaign
# education
# basic.4y             47.596504  2.600575   4176     4176
# basic.6y             40.448953  2.556283   2292     2292
# basic.9y             39.061208  2.532341   6045     6045
# high.school          37.998213  2.568576   9515     9515
# illiterate           48.500000  2.277778     18       18
# professional.course  40.080107  2.586115   5243     5243
# university.degree    38.879191  2.563527  12168    12168
# unknown              43.481225  2.596187   1731     1731
